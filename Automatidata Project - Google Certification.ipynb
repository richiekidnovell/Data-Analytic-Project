# %% [markdown]
# # **Automatidata project - Google Certification**

# %% [markdown]
# # README
#
# ## Project Overview
#
# In this project, I am working as a data professional at Automatidata, a fictional data consulting firm. My focus is on providing data-driven solutions and insights. The current task involves performing Exploratory Data Analysis (EDA) and data visualization for the New York City Taxi and Limousine Commission (New York City TLC).
#
# The goal is to gain a general understanding of taxi ridership patterns in New York City. Specifically, I aim to structure and clean the data, and then create meaningful visualizations using Python (Matplotlib/Seaborn) and Tableau. These visualizations should be easy to understand for non-technical stakeholders, and accessible to individuals with visual impairments.
#
# ## Tasks
#
# The tasks involved in this project are as follows:
#
# 1. **Data Structuring and Cleaning:** I will perform data cleaning operations on the NYC TLC dataset to ensure the data is consistent, accurate, and ready for analysis.
#
# 2. **Data Visualization (Python):** Using the Matplotlib and Seaborn libraries, I will generate a series of plots to better understand the data. These will include (but are not limited to) a box plot of ride durations and time series plots showing ride patterns broken down by quarter or month.
#
# 3. **Data Visualization (Tableau):** I will create a Tableau dashboard showing a map of New York City with taxi/limo trips categorized by month. The dashboard will be designed with accessibility in mind, particularly for individuals with visual impairments.
#
# ## Instructions
#
# This project includes a Python notebook that serves as a guide through the EDA and data visualization process. You are expected to complete the sections of the notebook where indicated. The notebook includes both code and markdown cells, which will guide you through the analysis and allow you to document your findings.
#
# ## Final Note
#
# Remember, the ultimate goal is to provide insights that are accessible and meaningful to a broad audience. My visualizations should tell a clear story about NYC taxi ridership and be easy to interpret for someone who isn’t data savvy

# %% [markdown]
# # **Visualize a story in Tableau and Python**

# %% [markdown]
# Throughout the process of this project, I'm making use of a problem-solving framework known as PACE. This acronym stands for Plan, Analyze, Construct, and Execute.
#
# 1. **Plan:** In the planning phase, I outline the steps I'm going to take to solve the problem. For this project, the problem is understanding taxi ridership patterns in New York City. My plan involves structuring and cleaning the data, then creating meaningful visualizations using Python and Tableau.
#
# 2. **Analyze:** In the analysis phase, I take a deep dive into the data. I look at the different variables, their relationships, and any patterns or trends that emerge. I use statistical techniques and data visualization tools to aid in this process.
#
# 3. **Construct:** The construction phase involves building the solution. In this case, that means creating the data visualizations that will help others understand the data. I use libraries like Matplotlib and Seaborn in Python, and also Tableau for creating a more interactive dashboard.
#
# 4. **Execute:** Finally, in the execution phase, I bring it all together. I make sure my visualizations are polished, easy to understand, and accessible to people with visual impairments. Then I present my findings to stakeholders.
#
# By following the PACE framework, I ensure a structured and thorough approach to solving the problem. Each stage builds upon the previous one, leading to a comprehensive solution.

# %% [markdown]
# ## PACE: Plan

# %% [markdown]
# ### 1. Identify any outliers:

# %% [markdown]
# **Visual Method**: Box plot, scatter plot, histogram. These methods work well for small to medium data sets
#
# **Z-Score**: Numerical measurement that describes a value's relationship to the mean of a group of valyes. Z-score is measured in terms of *standard deviation* from the mean. If z-score is - it indicates the data point score is identical to the mean score. If the score is 1.0 indicates a value that is one standar deviation from the mean.
#
# **IQR**: Interquartile Range is a measure of statistical dispersion, being equal to the difference between the upper and lower. Any data points that fall below the lowe quartile - 1.5 times or above the upper quartile _ 1.5 times the IQR could be considered an outlier
#
# **Modified Z-Score**: Uses the median and Median Absolute Deviation (MAD) instead od the mean and standard deviation
#
# **Keep or Not Keep Outlier**:If the outlier can be tracked back should be corrected if possible or excluded from the analsis otherwise. If the outliers does not change the result but does affect assumpstions, drop the ourliers. If the outliers change the resulrt, then it's even more critical to investigate and understand where it is coming from. Outliers can be indiative of important feature in the data. For example in fraud detection, fraudulent activities could often be flagged as outliers. In such scenarios, it's critical not to remove outliers as they contain valuable information.

# %% [markdown]
# ### Imports, links, and loading

# %%
# Import packages and libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset into dataframe
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')

# %% [markdown]
# ## PACE: Analyze

# %% [markdown]
# ### Data exploration and cleaning
#
# In the process of analyzing the taxi ridership dataset, here's how I would approach each of these considerations:
#
# 1. **Applicable Columns:** Based on the scenario, certain columns in the dataset may be more relevant than others. For example, ride duration, pickup and drop-off locations, number of passengers, fare amount, and tip amount are likely to be particularly important for understanding taxi ridership patterns. These columns could provide insights into when and where taxis are most in demand, how ride characteristics influence fare and tips, and so on.
#
# 2. **Eliminating Columns:** On the other hand, some columns may not be relevant to our scenario and can be eliminated to simplify the analysis. For example, if the dataset includes columns for payment method or driver ID, these might not be necessary for our current analysis.
#
# 3. **Understanding and Structuring the Data:** I would use various functions to get a sense of the data. `head()` to look at the first few rows, `describe()` to get summary statistics, `info()` to check data types and detect missing values, `groupby()` and `sortby()` to group and sort data based on certain criteria.
#
# 4. **Missing Data:** If there's any missing data, I would decide how to handle it based on the nature and amount of missingness. If only a small fraction of data is missing, it might be reasonable to drop those rows. If a significant amount is missing, I might consider imputation methods.
#
# 5. **Outliers:** If there are outliers in the data, I would first try to understand why they exist. If they're due to errors or anomalies, I might choose to remove or adjust them. If they're legitimate extreme values, I might leave them in, but consider robust statistical methods that are less sensitive to outliers.
#
# 6. **Distributions:** Looking at the distributions of variables can give me insights into the data. For example, if ride durations are heavily skewed, this might suggest that most rides are short but a few are much longer. This could influence how I handle these data in my analysis, such as by applying a transformation to reduce skewness.
#
# By going through these steps, I can ensure that I have a clean, well-structured dataset that's ready for analysis, and that I understand the key characteristics and patterns in the data.

# %%
df.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 10))
ax[0, 0].hist(df['passenger_count'], bins=range(1, 10), edgecolor='black')
ax[0, 0].set_title('Passenger Count Distribution')

ax[0, 1].hist(df['trip_distance'], bins=range(0, 100, 5), edgecolor='black')
ax[0, 1].set_title('Trip Distance Distribution (miles)')

ax[1, 0].hist(df['fare_amount'], bins=range(0, 100, 5), edgecolor='black')
ax[1, 0].set_title('Fare Amount Distribution ($)')

ax[1, 1].hist(df['total_amount'], bins=range(0, 100, 5), edgecolor='black')
ax[1, 1].set_title('Total Amount Distribution ($)')
# Out:
# Text(0.5, 1.0, 'Total Amount Distribution ($)')

# %% [markdown]
# **Passanger Count**: Most of the trips have 1 or 2 pasasnger. There are fewer trip with more than 2 passanger
#
# **Trip Distance**: Most of the trips are short, with distances of less then 20 miles. There are fewer long trips.
#
# **Fare Amount**: The fare amount for most trips is less than $20, with very few trips costing more than that.
#
# **Total Amount**: the total amount charged (including fares, tips and other charges) is also mostly less than $20

# %% [markdown]
# ### Select visualization type(s)

# %% [markdown]
# Deciding on the type of data visualization to use largely depends on the nature of the data and the specific insights you're trying to glean from it. Given the taxi ridership dataset, here's how I might use each type of visualization:

# %% [markdown]
# **Potential Use**
#
# **Line Graph**: Show trends overtime. For example, total `number of trips`, `average fare`, `total reveue per day` to see how these change over the course of the year.
#
# **Bar Chart**: This could be useful for comparing categorical variables. For example, you could create a bar chart of the `average fare` or `total trips` by `payment typ`e or `RateCodeID`
#
# **Box Plot**: THis is a great way to visualise the distribution of a numerical variable and identfy outliers. Use for `fare amount`, `tip amount`, `total amount`, `trip distance`
#
# **Histogram**: Visualise distribution of numerical variable with the same variable as Box Plot
#
# **Heat Map**: To show correlation between differnt numerical variables. Calcualte the correlation between `fare amount`, `tip amount`, `total amount`, `trip distance`, `passanger count` and to visualise the correlation matrix in heatmap
#
# **Scatter Plot**: USeful to show relationship between two numerical variables. For `Fare Amount` vs `tip amount` or `total amount` vs `trip distance`.
#
# **Geographic Map**: For Long and Lat data for the pickup and drop off locations. Create a map of the locations of all ppickups or dropoffs, or showing the average fare or total number of tips for each location.

# %% [markdown]
# ## PACE: Construct

# %% [markdown]
# ### Data visualization

# %% [markdown]
# ### Boxplots

# %% [markdown]
# Performing an outlier check on relevant columns, such as trip distance and trip duration, is an essential part of exploratory data analysis. Outliers can significantly impact the results of data analysis and statistical modeling, causing a skewed representation of the reality.
#
# To perform this check, I will leverage box plots and histograms - these are effective visualization tools for detecting outliers.
#
# A **box plot (or box-and-whisker plot)** shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset, while the whiskers extend to show the rest of the distribution, except for points that are determined to be outliers.

# %%
# Convert data columns to datetime
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %% [markdown]
# **trip distance**

# %%
plt.boxplot(df['trip_distance'], vert=False)
plt.title('Box Plot of Trip Distance in miles')
plt.show()

# %% [markdown]
# **Box Plot** Represent the interquarile range of the trip distance, with this line inside of the box representing the median. The `whiskers` extend to show the range of the data withing 1.5 times the interquartile range. Points outside of the whiskers are considered outliers and are plotted as individuals.
#
# **From the Plot**: Most of the trip distance are under 10 miles, with a median around 2 miles. There are also significant number of outliers, representing trips that are much longer thatn the typical trip. These could be longer trips to the airport, for example, or they could be due to errors or other unusual circumtances.

# %%
# Create histogram of trip_distance
plt.figure(figsize=(10,6))
plt.hist(df['trip_distance'], bins=range(0,100,5), edgecolor='black')
plt.title('Histogram of Trip Distance')
plt.xlabel('Trip Distance')
plt.ylabel('Range')
plt.show()

# %% [markdown]
# **Histogram**: A graphical representaton of the distribution of a dataset. It is an estimate of the probability distribution of a continuos variable
#
# **From Histogram**: Vast Majority of trips are short, with a distance of less than 10 miles. there are fewer trips with longer distances. This distribution is consistent with what we might expect for a dataset of a taxi trips in a city. Note that x-axis represents the trip distance, divided into bins of 5 miles each, y-axis represent the frequency. The bins with longer trip distances have lower frequencies, indicating that long trip are less common

# %% [markdown]
# **total amount**

# %%
# Create box plot of total_amount
plt.figure(figsize=(10, 6))
plt.boxplot(df['total_amount'],vert=False)
plt.title(' Box Plot for the Total Amoount')
plt.show()

# %% [markdown]
# **From BoxPlot**: We can observer that the most of the total amountst are undere approximately 20 with a median around $12. We can see that there are 2 massive outliers of 1200 and 400 and one outliers that have a minus value inside of it

# %%
# Create histogram of total_amount
plt.figure(figsize=(10,6))
plt.hist(df['total_amount'], bins=range(0, 100, 5), edgecolor='black')
plt.title('Histogram to indicate the total amount in ($)')
plt.xlabel('Total Amount ($)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **tip amount**

# %%
# Create box plot of tip_amount
plt.figure(figsize=(10,6))
plt.boxplot(df['tip_amount'], vert=False)
plt.title('Box Plot of the Tip Amount in $')
plt.show()

# %% [markdown]
# **From BoxPlot**: As shown above the median of the tip is 1 and most of the tips is approximately 3 dollars and some bigger tips from 50 and 200 is an outliers that need further analysis

# %%
# Create histogram of tip_amount
plt.figure(figsize=(10,6))
plt.hist(df['tip_amount'], bins=range(0,20,5), edgecolor='black')
plt.title('Histogram of the Tip Amount in $')
plt.xlabel('Frequency')
plt.ylabel('Amount in $')
plt.show()

# %% [markdown]
# **From Histogram**: Most of the tip is ranging from 0-3 dollar and there are still some that give above 5/10.

# %% [markdown]
# **tip_amount by vendor**

# %%
# Create histogram of tip_amount by vendor
df_non_zero = df[df['tip_amount'] > 0]

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

for vendor in [1, 2]:
    df_vendor = df_non_zero[df_non_zero['VendorID'] == vendor]
    ax[vendor-1].hist(df_vendor['tip_amount'], bins = 50, color='skyblue', edgecolor='black')
    
    ax[vendor-1].set_title(f'Vendor{vendor}')
    ax[vendor-1].set_xlabel('Tip Amount')
    ax[vendor-1].set_ylabel('Frquency')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Vendor 1**: Most of tips are in the lower end ranging from 0-20 and it is right skewed.
#
# **Vendor 2**: The pattern is the same as vendor 1. Most of the tips are on the lower end, another example of right-skewed

# %% [markdown]
# Next, zoom in on the upper end of the range of tips to check whether vendor one gets noticeably more of the most generous tips.

# %%
# Create histogram of tip_amount by vendor for tips > $10 
df_tip_10 = df[df['tip_amount'] > 10]

fig, ax = plt.subplots(1,2, figsize=(15,5))

for vendor in [1, 2]:
    df_vendor = df_tip_10[df_tip_10['VendorID'] == vendor]
    ax[vendor-1].hist(df_vendor['tip_amount'], bins=50, color='skyblue', edgecolor='black')
    ax[vendor-1].set_title(f'Vendor{vendor}')
    ax[vendor-1].set_xlabel('Frequency')
    ax[vendor-1].set_ylabel('Tip Amount')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Mean tips by passenger count**
#
# Examine the unique values in the `passenger_count` column.

# %%
df_unique_passanger = df['passenger_count'].unique()
df_unique_passanger
# Out:
# array([6, 1, 2, 4, 5, 3, 0])

# %% [markdown]
# The unique values in `passenger_count` are 0, 1, 2, 3,4 ,5 and 6. This suggest that the data include trips with anywhere from 0 to 6 passenger

# %%
# Calculate mean tips by passenger_count
mean_tips = df.groupby('passenger_count')['tip_amount'].mean()
mean_tips
# Out:
# passenger_count
# 0    2.135758
# 1    1.848920
# 2    1.856378
# 3    1.716768
# 4    1.530264
# 5    1.873185
# 6    1.720260
# Name: tip_amount, dtype: float64

# %% [markdown]
# Now as shown above there might be some error entry due to the `0` passanger have the average tips of 2.14. Please note that these are average and therefore may not represent all trips for each passanger count.

# %%
# Create bar plot for mean tips by passenger count
plt.figure(figsize=(10,6))
mean_tips.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Mean Tips By Passanger Count')
plt.xlabel('Frequency')
plt.ylabel('Tip Amount')
plt.show()

# %% [markdown]
# **Create month and day columns**

# %%
# Change Datatype
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

#Month Column
df['month'] = df['tpep_pickup_datetime'].dt.month

#Day Column
df['day'] = df['tpep_pickup_datetime'].dt.day


df[['tpep_pickup_datetime', 'month', 'day']].head()
# Out:
#   tpep_pickup_datetime  month  day
# 0  2017-03-25 08:55:43      3   25
# 1  2017-04-11 14:53:28      4   11
# 2  2017-12-15 07:26:56     12   15
# 3  2017-05-07 13:17:59      5    7
# 4  2017-04-15 23:32:20      4   15

# %% [markdown]
# **In this Output**:
#
# • The `Month` Column contains tht month part of the pirc up date (e.g 3 for march)
#
# • The `day` contain the day of the month (e.g 25 for 25th)

# %% [markdown]
# **Plot total ride count by month**
#
# Begin by calculating total ride count by month.

# %%
# Get total number of rides for each month
total_ride_month = df['month'].value_counts().sort_index()
total_ride_month
# Out:
# 1     1997
# 2     1769
# 3     2049
# 4     2019
# 5     2013
# 6     1964
# 7     1697
# 8     1724
# 9     1734
# 10    2027
# 11    1843
# 12    1863
# Name: month, dtype: int64

# %%
# Create a bar plot of total rides per month
total_ride_month.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Bar Plot of Total Rides Per Month')
plt.xlabel('Frequency')
plt.ylabel('Rides Amount')
plt.show()

# %% [markdown]
# **Plot total ride count by day**
#
# Repeat the above process, but now calculate the total rides by day of the week.

# %%
# Repeat the above process, this time for rides by day
total_ride_day = df['day'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
total_ride_day.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Bar Plot of Total Ride per Day')
plt.xlabel('Frequency')
plt.ylabel('Ride Amount')
plt.show()

# %% [markdown]
# **Plot total revenue by day of the week**
#
# Repeat the above process, but now calculate the total revenue by day of the week.

# %%
# Repeat the process, this time for total revenue by day
total_revenue_day = df.groupby('day')['total_amount'].sum()
plt.figure(figsize=(10,6))
total_revenue_day.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Bar Plot of Total Revenue per Day')
plt.xlabel('Frequency')
plt.ylabel('Revenue Amount')
plt.show()

# %% [markdown]
# **Plot total revenue by month**

# %%
# Repeat the process, this time for total revenue by month
total_revenue_month = df.groupby('month')['total_amount'].sum()
plt.figure(figsize=(10, 6))
total_revenue_month.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Total Revenue Per Month')
plt.xlabel('Frequency')
plt.ylabel('Revenue Amount')
# Out:
# Text(0, 0.5, 'Revenue Amount')

# %% [markdown]
# **Plot mean trip distance by drop-off location**

# %%
# Get number of unique drop-off location IDs
df_unique_dropoff = df['DOLocationID'].nunique()
df_unique_dropoff
# Out:
# 216

# %% [markdown]
# The number of unique Drop-Off Location IDs in the dataset is 216. This means that ther are 216 different location.

# %%
# Calculate the mean trip distance for each drop-off location
df_mean_distance_dropoff = df.groupby('DOLocationID')['trip_distance'].mean()

# Sort the results in descending order by mean trip distance
mean_distance_by_dropoff = df_mean_distance_dropoff.sort_values(ascending=False)
mean_distance_by_dropoff
# Out:
# DOLocationID
# 23     24.275000
# 29     21.650000
# 210    20.500000
# 11     17.945000
# 51     17.310000
#          ...
# 137     1.818852
# 234     1.727806
# 237     1.555494
# 193     1.390556
# 207     1.200000
# Name: trip_distance, Length: 216, dtype: float64

# %% [markdown]
# This shows the drop-off location with the highest mean trip. For example, the drop-off location with ID 23 has the highest maen approx 24.27 miles

# %%
# Create a bar plot of mean trip distances by drop-off location in ascending order by distance
mean_distance_by_dropoff.plot(kind='bar',figsize=(40, 6), color='skyblue', edgecolor='black')
# Set the title and labels
plt.title('Mean Trip Distance by Drop-off Location')
plt.xlabel('Drop-off Location ID')
plt.ylabel('Mean Trip Distance (miles)')

# Show the plot
plt.show()

# %% [markdown]
# Here is the bar plot showing the mean trip distance for each drop-off location, sorted in descending order by distance.
#
# From the graph, we can observe that there's a wide range of mean trip distances across the different drop-off locations. Some locations have a high mean trip distance, indicating that trips to these locations tend to be longer on average. On the other hand, some locations have a low mean trip distance, indicating that trips to these locations tend to be shorter.
#
# This visualization provides a clear picture of how the mean trip distance varies by drop-off location. However, keep in mind that these are average distances, so the actual trip distance can vary widely within each location.

# %% [markdown]
# ## EXPERIMENT
#
# To confirm conclusion, consider the following experiment:
# 1. Create a sample of coordinates from a normal distribution&mdash;in this case 1,500 pairs of points from a normal distribution with a mean of 10 and a standard deviation of 5
# 2. Calculate the distance between each pair of coordinates
# 3. Group the coordinates by endpoint and calculate the mean distance between that endpoint and all other points it was paired with
# 4. Plot the mean distance for each unique endpoint

# %%
# Set the seed for reproducibility
np.random.seed(0)

# Generate 1500 pairs of points from a normal distribution
num_pairs = 1500
points = np.random.normal(loc=10, scale=5, size=(num_pairs, 2, 2))

# Calculate the Euclidean distance between each pair of points
distances = np.linalg.norm(points[:, 0, :] - points[:, 1, :], axis=1)

# Create a DataFrame with the endpoints and distances
data = pd.DataFrame({
    'endpoint_1': points[:, 0, :].tolist(),
    'endpoint_2': points[:, 1, :].tolist(),
    'distance': distances
})

# Display the first few rows of the DataFrame
data.head()
# Out:
#                                  endpoint_1  \
# 0   [18.82026172983832, 12.000786041836117]
# 1   [19.337789950749837, 5.113610600617945]
# 2    [9.48390574103221, 12.052992509691862]
# 3  [13.805188625734967, 10.608375082464143]
# 4    [17.47039536578803, 8.974208681170996]
#
#                                  endpoint_2   distance
# 0   [14.893689920528697, 21.20446599600729]  10.006283
# 1   [14.750442087627947, 9.243213958511511]   6.172308
# 2  [10.720217855804389, 17.271367534814875]   5.362826
# 3  [12.219316163727129, 11.668371636871335]   1.907507
# 4   [11.565338508254507, 5.729521303491376]   6.737781

# %% [markdown]
# Next, we'll "flatten" this DataFrame so that each row represents an endpoint (either 'endpoint_1' or 'endpoint_2') and its associated distance. This will allow us to group the data by endpoint and calculate the mean distance for each unique endpoint.

# %%
# Flatten the DataFrame
df_flat = pd.concat([
    data[['endpoint_1', 'distance']].rename(columns={'endpoint_1': 'endpoint'}),
    data[['endpoint_2', 'distance']].rename(columns={'endpoint_2': 'endpoint'})
])

# %%
df_flat['endpoint'] = df_flat['endpoint'].apply(tuple)

# Group by endpoint and calculate mean distance
mean_distance_by_endpoint = df_flat.groupby('endpoint')['distance'].mean()

# Display the mean distance for each unique endpoint
mean_distance_by_endpoint
# Out:
# endpoint
# (-8.700503189758894, 14.867883975940789)     26.721957
# (-5.5842829579956295, 13.222260167055211)    19.160653
# (-5.032493575036632, 9.764170661733791)      14.814184
# (-4.973064301138095, 14.404687805404858)     17.705349
# (-4.160059349544936, 4.582866698678601)      14.062610
#                                                ...
# (24.407303565819817, 7.030690423086561)      16.401715
# (24.645481208819305, 11.114291615517434)     13.211831
# (25.854873866450898, 10.947498187739567)     17.181255
# (26.532871745552807, 2.4490017801092945)     19.362645
# (29.008301074835575, 21.575853170029724)     27.341333
# Name: distance, Length: 3000, dtype: float64

# %% [markdown]
# Now we have successfully calculated the mean distance for each unique endpoint. Each row of the output represents an endpoint (a 2D coordinate) and the mean distance between that endpoint and all other points it was connected with.
#
# Lastly, let's plot the mean distance for each unique endpoint. To make the plot more readable, we'll only plot a subset of the endpoints. Let's say, the 50 endpoints with the highest mean distance.

# %%
# Get the 50 endpoints with the highest mean distance
top_endpoints = mean_distance_by_endpoint.nlargest(50)

# Create a bar plot for the mean distance for each unique endpoint
plt.figure(figsize=(10, 10))
plt.barh(range(len(top_endpoints)), top_endpoints.values, color='skyblue', edgecolor='black')
plt.yticks(range(len(top_endpoints)), top_endpoints.index)

# Set the title and labels
plt.title('Mean Distance for Each Unique Endpoint')
plt.xlabel('Mean Distance')
plt.ylabel('Endpoint')

# Show the plot
plt.show()

# %% [markdown]
# **Histogram of rides by drop-off location**

# %% [markdown]
# Here is the bar plot showing the mean distance for each of the 50 unique endpoints with the highest mean distances.
#
# Each bar represents an endpoint (a 2D coordinate), and the length of the bar represents the mean distance between that endpoint and all other points it was connected with.
#
# This visualization provides a clear picture of how the mean distance varies by endpoint. However, keep in mind that these are average distances, so the actual distances can vary widely for each endpoint.

# %%
# Check if the drop-off locations IDs are consecutively numbered
dropoff_location_ids = df['DOLocationID'].unique()
dropoff_location_ids.sort()

# Create a range of consecutive numbers from the minimum to the maximum drop-off location ID
consecutive_ids = np.arange(dropoff_location_ids.min(), dropoff_location_ids.max() + 1)

# Check if any IDs are missing
missing_ids = set(consecutive_ids) - set(dropoff_location_ids)
missing_ids
# Out:
# {2,
#  3,
#  5,
#  6,
#  8,
#  20,
#  27,
#  30,
#  44,
#  46,
#  57,
#  58,
#  59,
#  84,
#  96,
#  99,
#  101,
#  103,
#  104,
#  105,
#  108,
#  109,
#  110,
#  111,
#  115,
#  122,
#  128,
#  139,
#  154,
#  155,
#  156,
#  165,
#  167,
#  172,
#  176,
#  185,
#  187,
#  191,
#  199,
#  203,
#  204,
#  206,
#  214,
#  221,
#  245,
#  250,
#  251,
#  253,
#  254}

# %% [markdown]
# Yes, there are some drop-off location IDs that are missing. These are the missing IDs:
#
# {2, 3, 5, 6, 8, 20, 27, 30, 44, 46, 57, 58, 59, 84, 96, 99, 101, 103, 104, 105, 108, 109, 110, 111, 115, 122, 128, 139, 154, 155, 156, 165, 167, 172, 176, 185, 187, 191, 199, 203, 204, 206, 214, 221, 245, 250, 251, 253, 254}
#
# This means that the drop-off locations IDs are not consecutively numbered. If we were to create a histogram with the current data, there would be gaps where these missing IDs are. Therefore, it's important to keep this in mind when analyzing or visualizing the data based on the drop-off location IDs.

# %%
# Sort the unique drop-off location IDs and convert them to strings
df['DOLocationID_str'] = df['DOLocationID'].sort_values().astype(str)

# Display the first few rows of the DataFrame
df[['DOLocationID', 'DOLocationID_str']].head()
# Out:
#    DOLocationID DOLocationID_str
# 0           231              231
# 1            43               43
# 2           236              236
# 3            97               97
# 4           112              112

# %% [markdown]
# Now, we can create a histogram with the 'DOLocationID_str' column to visualize the number of rides for each drop-off location without having gaps for missing IDs. Let's proceed with creating the histogram.

# %%
import seaborn as sns

# Create a histogram of ride counts by drop-off location
plt.figure(figsize=(20, 6))
sns.histplot(data=df, x='DOLocationID_str', bins=50, color='skyblue', edgecolor='black')

# Set the title and labels
plt.title('Number of Rides by Drop-off Location')
plt.xlabel('Drop-off Location ID')
plt.ylabel('Number of Rides')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# Here is the histogram showing the number of rides for each drop-off location. The drop-off location IDs are represented as strings, so all bars are displayed directly next to each other, eliminating gaps for missing IDs.
#
# Each bar represents a drop-off location, and the height of the bar represents the number of rides that ended at that location. You can see how the number of rides varies by drop-off location.
#
# However, due to the large number of unique drop-off locations, the labels on the x-axis are not clearly visible, even after rotating them. If you want a clearer visualization, you might consider grouping the drop-off locations in a meaningful way or focusing on a subset of the locations.

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
#
#
# ## PACE: Execute

# %% [markdown]
# ### Results and evaluation

# %% [markdown]
# Having built visualizations in Tableau and in Python, here are some insights we can infer about the dataset:
#
# 1. The dataset is rich in information. It contains several attributes like trip distance, fare amount, tip amount, pickup and drop-off locations, etc., that can be used to analyze various aspects of the taxi rides.
# 2. The number of rides fluctuates throughout the year, with certain months having higher ride counts than others.
# 3. The mean tip amount varies with the number of passengers, with certain passenger counts associated with higher tips on average.
# 4. There is a wide range of mean trip distances across different drop-off locations. Some locations are associated with longer trips on average, while others are associated with shorter trips.
#
# These visualizations have uncovered several interesting patterns and have raised further questions:
#
# 1. What factors contribute to the variation in the number of rides throughout the year? Could it be related to holidays, tourist seasons, or weather conditions?
# 2. Why does the mean tip amount vary with the number of passengers? Does the number of passengers affect the quality of service, and therefore the tip amount?
# 3. Why do some drop-off locations have longer mean trip distances? Are these locations far from common pickup locations, or are they popular long-distance destinations?
# 4. How does the time of day affect the trip distance, fare amount, and tip amount?
#
# From a client's perspective, they would likely want to know:
#
# 1. What are the peak hours for taxi rides, and how does the demand vary throughout the day? This information could help optimize taxi availability.
# 2. How does the fare amount and tip amount vary by location, time, and other factors? This could provide insights into pricing strategies.
# 3. Are there any patterns or trends in the data that could be used to predict future demand? This could be valuable for planning and resource allocation.
#
# To make the visualizations more accessible and easily understandable, I ensured to use clear labels for the axes and titles for the plots. I also used color to differentiate between different groups of data, and made sure there is sufficient contrast between different colors. I also considered the emphasis, ensuring that the most important information stands out.
#
# In addition to the above, I could also consider using interactive visualizations, which would allow the viewer to explore the data in more depth. For example, I could use a tool like Plotly to create interactive plots that the viewer can zoom in and out of, hover over for more information, or click on to filter the data.
#
# Finally, it's important to keep in mind the principles of data visualization, such as simplicity, clarity, and honesty. The goal should be to communicate the information in the data as clearly and accurately as possible, without adding unnecessary complexity or potential for misinterpretation.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# 1. **Understanding the Data:** EDA is the first step in the data analysis process. It provides a high-level view of the data and helps us understand the structure, characteristics, and relationships within the data. This understanding is critical for making informed decisions about modeling and prediction.
#
# 2. **Identifying Patterns and Relationships:** EDA includes techniques such as visualization that help to uncover patterns, correlations, and relationships between variables. These insights can be valuable for hypothesis generation and feature selection in machine learning.
#
# 3. **Data Cleaning:** EDA helps us identify anomalies, outliers, and errors in the data, such as missing or inconsistent values. Cleaning up these issues improves the quality of the data and the accuracy of the analysis.
#
# 4. **Assumptions Verification:** EDA can help verify or refute assumptions made about the data. This could influence the choice of statistical techniques or algorithms used in later analysis.
#
# 5. **Informing Feature Engineering:** By understanding the relationships and distributions in the data, EDA can inform the creation of new features that better represent the underlying patterns in the data.
#
# The data visualizations provided in this notebook are useful in several ways:
#
# 1. **Quick Insights:** Visualizations help in understanding complex data sets by representing information in a graphical format. This allows for quicker interpretation of data, identification of trends, patterns, and outliers which might not be immediately apparent in tabular data.
#
# 2. **Effective Communication:** Visualizations are an effective way to communicate findings to both technical and non-technical stakeholders. They can convey insights from the data in a manner that is easy to understand and can be used to tell a story about the data.
#
# 3. **Guiding Analysis:** The process of creating visualizations can also generate new questions and lead to further analysis. For instance, seeing an unexpected pattern in a plot might lead you to investigate a certain feature more closely.
#
# 4. **Decision-Making:** By summarizing and presenting data in a way that highlights key points, visualizations can aid in decision-making processes. For example, showing the distribution of taxi rides over time can help in resource planning and optimization.
#
# In conclusion, EDA and data visualizations are critical components of any data analysis process. They provide the foundation for understanding the data, generating insights, making informed decisions, and communicating results effectively.
